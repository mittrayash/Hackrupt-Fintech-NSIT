# %%
import pandas as pd
import numpy as np
import random

# %%
reg_id = []
ac_bal = []
p_loans_no = []
act_loans_no = []
p_loans_no =[]
act_loans_no = [] 
ref_no =[]
fd = []

# %%
def list_loan_gen(len,num):
    x = []
    if num == 0: 
        for i in range(0, len):
            x.append(random.randint(0,1000)*10000) 
    else:
        for i in range(0, len):
            x.append(random.randint(1, 5))
    return x

def twoD_loan_gen(p_loans, num):
    x = []
    for i in p_loans:
        x.append(list_loan_gen(i, num))
    return x

for i in range(0, 1000):
    reg_id.append(random.randint(1000, 9999))
    ac_bal.append(int(random.random()*10000000))
    p_loans_no.append(int(random.randint(0, 3)))
    act_loans_no.append(int(random.randint(0, 1)))
    ref_no.append(int(random.randint(0, 3)))
    fd.append(int(random.randint(0, 100)*1000))
    
ref = twoD_loan_gen(ref_no, 1)
p_loans = twoD_loan_gen(p_loans_no, 0)
act_loans = twoD_loan_gen(act_loans_no, 0)

# %%
df = pd.DataFrame(data={'ID':reg_id, 'A/c Bal':ac_bal, 'Paid Loans':p_loans, 'Active Loans':act_loans, 'Level of Referees':ref, 'Fixed Deposit':fd})
df.head()
# Out:
#    A/c Bal Active Loans  Fixed Deposit    ID Level of Referees Paid Loans
# 0  4311534    [6660000]          98000  3855            [3, 3]  [5420000]
# 1  8335207           []          49000  8823         [1, 3, 3]         []
# 2  7634779           []          70000  2368         [4, 1, 3]         []
# 3  7351828    [7210000]          79000  7123            [1, 4]  [6430000]
# 4  1955267           []          92000  4286         [4, 3, 1]  [7810000]

# %%
cols = df.columns.tolist()
cols = ['ID', 'A/c Bal', 'Fixed Deposit', 'Active Loans', 'Level of Referees', 'Paid Loans']
df = df[cols]
df
# Out:
#        ID  A/c Bal  Fixed Deposit Active Loans Level of Referees  \
# 0    3855  4311534          98000    [6660000]            [3, 3]
# 1    8823  8335207          49000           []         [1, 3, 3]
# 2    2368  7634779          70000           []         [4, 1, 3]
# 3    7123  7351828          79000    [7210000]            [1, 4]
# 4    4286  1955267          92000           []         [4, 3, 1]
# 5    6037  6551122          45000    [1930000]                []
# 6    2542   568208          35000           []            [3, 1]
# 7    9409  3821089          58000    [1240000]         [4, 3, 3]
# 8    7333  5924078          35000           []         [2, 5, 4]
# 9    7227  6549043          71000           []                []
# 10   7024  6405684              0           []            [3, 3]
# 11   7118  2263267          85000    [9520000]                []
# 12   8113  4733874          94000           []            [5, 5]
# 13   5048  5840329          47000    [7560000]         [5, 4, 1]
# 14   8566  4083279          99000           []               [2]
# 15   6736  6470368          76000           []         [1, 1, 3]
# 16   8039  2513127          40000    [5110000]         [5, 2, 5]
# 17   3434  8696752          83000           []            [2, 5]
# 18   9856  2545371           9000    [7500000]            [3, 2]
# 19   7836  8252725          40000           []         [3, 2, 5]
# 20   9092  3354967           7000           []         [1, 1, 3]
# 21   3542  9954368          95000    [8760000]            [3, 4]
# 22   6670  1375616          78000    [7040000]               [3]
# 23   6555  1992237          88000    [4710000]                []
# 24   9696  6563642          77000    [4500000]               [1]
# 25   5974  9986480              0    [1390000]               [2]
# 26   2899   150812          99000           []         [1, 5, 1]
# 27   9303  8114220          50000           []                []
# 28   9100  3374117          41000    [6000000]               [5]
# 29   4499  6553585          85000    [4580000]            [4, 1]
# ..    ...      ...            ...          ...               ...
# 970  3631  1426639          95000    [9580000]                []
# 971  8662  2854547          62000    [5280000]            [3, 1]
# 972  5667  4665587          35000     [770000]            [4, 3]
# 973  5062  6305063          45000    [6600000]            [3, 4]
# 974  8504  9146402          23000     [670000]                []
# 975  3878  2605112          36000    [2190000]               [3]
# 976  5138  9849970          98000     [680000]         [5, 4, 2]
# 977  4181  1143935          22000    [7920000]            [4, 3]
# 978  2254  1265537          23000    [4660000]               [2]
# 979  6583  5823994          55000           []                []
# 980  9965  5268508          49000    [1210000]                []
# 981  1584  4754138          85000    [9600000]         [4, 3, 2]
# 982  9768  2259581          11000     [530000]               [4]
# 983  4343  9824938          74000           []                []
# 984  9138   812937          71000           []         [2, 5, 1]
# 985  5401  4535149          55000    [3840000]               [3]
# 986  3235  2947160          93000    [2290000]                []
# 987  3775  1027486           7000    [5410000]                []
# 988  9105  6654396           7000    [9120000]               [4]
# 989  2560  3079541          63000           []                []
# 990  8296  7161438          68000           []         [4, 4, 5]
# 991  3491  1890208          30000    [4260000]            [5, 5]
# 992  2990  1364425          48000           []                []
# 993  2671  1389794          51000     [160000]            [4, 5]
# 994  8596  5419878          10000    [6830000]                []
# 995  4375  8879545          51000           []            [2, 5]
# 996  7239  8301109           9000    [6590000]         [5, 5, 2]
# 997  9703   349074          95000           []               [4]
# 998  7774  5893888          67000           []               [3]
# 999  6555  3189338          13000           []         [5, 3, 1]
#
#                       Paid Loans
# 0                      [5420000]
# 1                             []
# 2                             []
# 3                      [6430000]
# 4                      [7810000]
# 5             [2520000, 9780000]
# 6    [3990000, 5710000, 4180000]
# 7             [7850000, 1560000]
# 8    [9130000, 3570000, 9070000]
# 9                             []
# 10                            []
# 11            [5830000, 4030000]
# 12                     [8640000]
# 13                            []
# 14                            []
# 15                     [5110000]
# 16      [100000, 10000, 4250000]
# 17            [8350000, 9200000]
# 18            [4340000, 5900000]
# 19                     [5090000]
# 20   [2150000, 8220000, 7670000]
# 21            [5800000, 4220000]
# 22                     [8200000]
# 23                     [7080000]
# 24            [4490000, 7040000]
# 25            [9920000, 8890000]
# 26                     [2230000]
# 27                     [1290000]
# 28                     [7870000]
# 29                     [6420000]
# ..                           ...
# 970                    [5370000]
# 971           [3040000, 3440000]
# 972  [9210000, 3670000, 6760000]
# 973                           []
# 974                           []
# 975  [5330000, 1510000, 3420000]
# 976            [4060000, 460000]
# 977             [1610000, 40000]
# 978  [6290000, 6680000, 8400000]
# 979                     [730000]
# 980           [5520000, 8980000]
# 981           [4810000, 4910000]
# 982                    [2960000]
# 983                           []
# 984                           []
# 985                           []
# 986           [9190000, 3710000]
# 987  [5850000, 6330000, 3980000]
# 988                           []
# 989                    [1190000]
# 990           [9950000, 7050000]
# 991           [7450000, 5760000]
# 992           [7210000, 7830000]
# 993           [8970000, 9960000]
# 994                    [3740000]
# 995           [3030000, 8320000]
# 996           [3900000, 9090000]
# 997                    [8030000]
# 998                    [5240000]
# 999                           []
#
# [1000 rows x 6 columns]

# %%
df['col12'] = df['A/c Bal']+df['Fixed Deposit']

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df['col12'] = scaler.fit_transform(df['col12'].reshape(-1,1))
# Out:
# C:\Users\mittr\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   """
# C:\Users\mittr\Anaconda3\lib\site-packages\sklearn\utils\validation.py:444: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
x = [] 
for i in df['Paid Loans']:
    if(len(i)>0):
        k = 0
        for j in range(0,len(i)):
            k = k + i[j]
        x.append(k)
    else:
        x.append(0)
x

#df['Paid Loans']
# Out:
# [5420000,
#  0,
#  0,
#  6430000,
#  7810000,
#  12300000,
#  13880000,
#  9410000,
#  21770000,
#  0,
#  0,
#  9860000,
#  8640000,
#  0,
#  0,
#  5110000,
#  4360000,
#  17550000,
#  10240000,
#  5090000,
#  18040000,
#  10020000,
#  8200000,
#  7080000,
#  11530000,
#  18810000,
#  2230000,
#  1290000,
#  7870000,
#  6420000,
#  0,
#  9450000,
#  6160000,
#  12460000,
#  1670000,
#  0,
#  2900000,
#  4960000,
#  13280000,
#  530000,
#  16570000,
#  14100000,
#  10120000,
#  9730000,
#  5640000,
#  9180000,
#  18890000,
#  1790000,
#  25650000,
#  11350000,
#  6190000,
#  19400000,
#  1960000,
#  0,
#  3500000,
#  0,
#  6670000,
#  9030000,
#  9640000,
#  3800000,
#  13550000,
#  9250000,
#  13150000,
#  5700000,
#  13670000,
#  420000,
#  0,
#  13000000,
#  4130000,
#  13510000,
#  3510000,
#  0,
#  6520000,
#  12640000,
#  320000,
#  3530000,
#  13350000,
#  0,
#  11360000,
#  19770000,
#  8110000,
#  24220000,
#  5530000,
#  14040000,
#  0,
#  9600000,
#  20310000,
#  6980000,
#  9160000,
#  12950000,
#  14250000,
#  15750000,
#  11570000,
#  0,
#  8790000,
#  9340000,
#  1910000,
#  3800000,
#  6930000,
#  11460000,
#  19910000,
#  5110000,
#  2230000,
#  9120000,
#  0,
#  0,
#  9510000,
#  24130000,
#  12150000,
#  0,
#  0,
#  9900000,
#  9210000,
#  8050000,
#  12770000,
#  4620000,
#  0,
#  8080000,
#  0,
#  7750000,
#  8480000,
#  0,
#  0,
#  11290000,
#  0,
#  0,
#  3770000,
#  3070000,
#  0,
#  5570000,
#  5240000,
#  4560000,
#  17380000,
#  19740000,
#  0,
#  1070000,
#  0,
#  2740000,
#  10560000,
#  14090000,
#  2680000,
#  0,
#  0,
#  0,
#  20030000,
#  7100000,
#  13300000,
#  7980000,
#  0,
#  0,
#  6390000,
#  0,
#  9240000,
#  22660000,
#  9560000,
#  10900000,
#  11500000,
#  16940000,
#  9950000,
#  7130000,
#  3050000,
#  5210000,
#  2870000,
#  12530000,
#  21610000,
#  0,
#  16980000,
#  11350000,
#  0,
#  6560000,
#  0,
#  0,
#  8470000,
#  11550000,
#  0,
#  0,
#  7210000,
#  11160000,
#  11800000,
#  4230000,
#  0,
#  0,
#  0,
#  4080000,
#  6520000,
#  8590000,
#  2260000,
#  11200000,
#  23860000,
#  12510000,
#  5880000,
#  7070000,
#  0,
#  0,
#  0,
#  10070000,
#  540000,
#  2580000,
#  19710000,
#  0,
#  0,
#  11480000,
#  9960000,
#  19930000,
#  3460000,
#  5070000,
#  17160000,
#  0,
#  10000000,
#  0,
#  1100000,
#  11130000,
#  9140000,
#  0,
#  0,
#  0,
#  15820000,
#  15650000,
#  8570000,
#  0,
#  11540000,
#  10560000,
#  6080000,
#  0,
#  9820000,
#  0,
#  6280000,
#  0,
#  0,
#  3710000,
#  8350000,
#  13070000,
#  0,
#  11440000,
#  0,
#  2130000,
#  4360000,
#  0,
#  600000,
#  9890000,
#  9360000,
#  13770000,
#  3880000,
#  560000,
#  0,
#  5410000,
#  11960000,
#  9480000,
#  1610000,
#  5490000,
#  18880000,
#  15170000,
#  6370000,
#  9920000,
#  2010000,
#  1690000,
#  11820000,
#  3310000,
#  8150000,
#  13200000,
#  1750000,
#  18220000,
#  10620000,
#  14530000,
#  0,
#  10730000,
#  0,
#  0,
#  9240000,
#  12080000,
#  780000,
#  3390000,
#  0,
#  3740000,
#  2750000,
#  9420000,
#  17900000,
#  0,
#  5180000,
#  6520000,
#  15160000,
#  6140000,
#  13730000,
#  5330000,
#  0,
#  0,
#  7270000,
#  18140000,
#  0,
#  1200000,
#  10700000,
#  13240000,
#  8920000,
#  2720000,
#  12150000,
#  0,
#  22510000,
#  2430000,
#  8490000,
#  7950000,
#  10320000,
#  0,
#  1630000,
#  25860000,
#  20540000,
#  10920000,
#  0,
#  7620000,
#  9510000,
#  6750000,
#  0,
#  4880000,
#  15370000,
#  10370000,
#  9800000,
#  19780000,
#  7740000,
#  590000,
#  5200000,
#  9660000,
#  16600000,
#  7680000,
#  23080000,
#  0,
#  0,
#  10440000,
#  15890000,
#  20150000,
#  0,
#  11620000,
#  0,
#  9570000,
#  15090000,
#  0,
#  0,
#  8290000,
#  0,
#  12420000,
#  8070000,
#  1300000,
#  20130000,
#  22910000,
#  0,
#  9780000,
#  0,
#  12390000,
#  17180000,
#  17630000,
#  0,
#  12630000,
#  9380000,
#  9000000,
#  9680000,
#  0,
#  0,
#  0,
#  6710000,
#  9360000,
#  4040000,
#  7020000,
#  8750000,
#  14480000,
#  0,
#  14200000,
#  1750000,
#  6500000,
#  0,
#  9840000,
#  0,
#  9480000,
#  15090000,
#  12930000,
#  2460000,
#  2350000,
#  0,
#  0,
#  3810000,
#  6580000,
#  7490000,
#  10490000,
#  10810000,
#  0,
#  26760000,
#  9140000,
#  0,
#  11720000,
#  11990000,
#  9320000,
#  7510000,
#  0,
#  21210000,
#  0,
#  850000,
#  13020000,
#  9310000,
#  20790000,
#  0,
#  4430000,
#  16870000,
#  11100000,
#  12230000,
#  11270000,
#  21550000,
#  0,
#  4190000,
#  9800000,
#  19250000,
#  4720000,
#  17840000,
#  5700000,
#  11540000,
#  14580000,
#  19820000,
#  2910000,
#  18780000,
#  10800000,
#  17900000,
#  0,
#  10170000,
#  7520000,
#  18060000,
#  3860000,
#  0,
#  8040000,
#  0,
#  13480000,
#  7920000,
#  14700000,
#  11780000,
#  17340000,
#  2240000,
#  0,
#  0,
#  11620000,
#  0,
#  0,
#  22830000,
#  12410000,
#  12200000,
#  8430000,
#  12700000,
#  0,
#  15770000,
#  5760000,
#  12670000,
#  0,
#  22070000,
#  17790000,
#  12220000,
#  9470000,
#  0,
#  7960000,
#  12200000,
#  7320000,
#  6510000,
#  7600000,
#  5260000,
#  400000,
#  7320000,
#  6190000,
#  0,
#  10390000,
#  16940000,
#  0,
#  0,
#  0,
#  14440000,
#  13230000,
#  9230000,
#  0,
#  4620000,
#  6670000,
#  14880000,
#  8230000,
#  3290000,
#  14560000,
#  1620000,
#  11490000,
#  0,
#  10850000,
#  2710000,
#  8350000,
#  5800000,
#  0,
#  8010000,
#  9280000,
#  9470000,
#  0,
#  0,
#  0,
#  4880000,
#  6180000,
#  18300000,
#  0,
#  3220000,
#  0,
#  20090000,
#  9250000,
#  0,
#  2720000,
#  0,
#  0,
#  23930000,
#  8530000,
#  7670000,
#  6130000,
#  0,
#  19080000,
#  9180000,
#  13340000,
#  0,
#  0,
#  21940000,
#  17810000,
#  1570000,
#  0,
#  14300000,
#  0,
#  4820000,
#  11860000,
#  13930000,
#  8060000,
#  4490000,
#  0,
#  18400000,
#  10310000,
#  1660000,
#  11380000,
#  12050000,
#  21420000,
#  1550000,
#  10160000,
#  4720000,
#  15810000,
#  4210000,
#  16990000,
#  9510000,
#  14870000,
#  0,
#  8730000,
#  15640000,
#  4110000,
#  0,
#  0,
#  4930000,
#  5300000,
#  0,
#  0,
#  0,
#  0,
#  1850000,
#  14560000,
#  1150000,
#  4760000,
#  5390000,
#  0,
#  18280000,
#  15340000,
#  12220000,
#  0,
#  6050000,
#  19820000,
#  13210000,
#  6860000,
#  3690000,
#  0,
#  80000,
#  6350000,
#  6370000,
#  9340000,
#  4580000,
#  5780000,
#  5540000,
#  15660000,
#  7810000,
#  0,
#  8000000,
#  11360000,
#  9210000,
#  0,
#  1930000,
#  9570000,
#  18300000,
#  9920000,
#  12510000,
#  7140000,
#  16030000,
#  12090000,
#  8070000,
#  0,
#  0,
#  2080000,
#  25910000,
#  12070000,
#  0,
#  3210000,
#  10980000,
#  0,
#  17130000,
#  0,
#  12410000,
#  14520000,
#  0,
#  16940000,
#  4650000,
#  1260000,
#  14320000,
#  12150000,
#  8960000,
#  5900000,
#  9900000,
#  14060000,
#  8500000,
#  25840000,
#  7430000,
#  6520000,
#  0,
#  0,
#  9410000,
#  0,
#  20180000,
#  15640000,
#  0,
#  0,
#  7780000,
#  13000000,
#  8800000,
#  13350000,
#  8680000,
#  18230000,
#  8440000,
#  0,
#  24630000,
#  7680000,
#  14200000,
#  2060000,
#  14280000,
#  0,
#  0,
#  20040000,
#  3950000,
#  14730000,
#  8830000,
#  8930000,
#  9900000,
#  5200000,
#  5910000,
#  6800000,
#  0,
#  0,
#  22710000,
#  730000,
#  0,
#  12580000,
#  7380000,
#  9720000,
#  13650000,
#  5570000,
#  0,
#  22770000,
#  15370000,
#  14860000,
#  8370000,
#  7730000,
#  10250000,
#  15160000,
#  3440000,
#  9880000,
#  6530000,
#  0,
#  0,
#  0,
#  7070000,
#  13830000,
#  13830000,
#  2860000,
#  13660000,
#  7160000,
#  20330000,
#  0,
#  9800000,
#  16130000,
#  11410000,
#  14670000,
#  0,
#  0,
#  13610000,
#  9960000,
#  5310000,
#  9520000,
#  18580000,
#  17890000,
#  0,
#  9940000,
#  9630000,
#  8300000,
#  16470000,
#  0,
#  8580000,
#  3120000,
#  3160000,
#  0,
#  0,
#  0,
#  18290000,
#  0,
#  0,
#  13220000,
#  8520000,
#  0,
#  9150000,
#  12580000,
#  0,
#  0,
#  2040000,
#  6990000,
#  5410000,
#  1980000,
#  0,
#  5770000,
#  13490000,
#  18920000,
#  9430000,
#  290000,
#  18980000,
#  7760000,
#  7890000,
#  8860000,
#  20240000,
#  2810000,
#  12530000,
#  14200000,
#  12980000,
#  1950000,
#  0,
#  0,
#  0,
#  13480000,
#  14870000,
#  1480000,
#  0,
#  0,
#  10020000,
#  4460000,
#  200000,
#  9590000,
#  12170000,
#  14510000,
#  7320000,
#  5690000,
#  14010000,
#  3780000,
#  12880000,
#  8240000,
#  20000,
#  0,
#  13350000,
#  15520000,
#  1700000,
#  6600000,
#  0,
#  8150000,
#  470000,
#  1840000,
#  0,
#  14950000,
#  18110000,
#  17800000,
#  650000,
#  11890000,
#  15010000,
#  18840000,
#  1570000,
#  14700000,
#  2130000,
#  13690000,
#  10400000,
#  280000,
#  0,
#  4350000,
#  5980000,
#  8590000,
#  4070000,
#  17530000,
#  14640000,
#  11970000,
#  7370000,
#  16900000,
#  9410000,
#  5960000,
#  7430000,
#  8340000,
#  9690000,
#  9590000,
#  6930000,
#  0,
#  7270000,
#  0,
#  0,
#  0,
#  0,
#  6170000,
#  1560000,
#  2400000,
#  16130000,
#  0,
#  15630000,
#  1840000,
#  7490000,
#  12560000,
#  1060000,
#  0,
#  8100000,
#  0,
#  0,
#  16610000,
#  0,
#  4560000,
#  8220000,
#  18370000,
#  7330000,
#  0,
#  4180000,
#  0,
#  4780000,
#  2430000,
#  12360000,
#  9060000,
#  7920000,
#  6780000,
#  16200000,
#  11130000,
#  0,
#  15120000,
#  0,
#  25110000,
#  4930000,
#  9770000,
#  21450000,
#  3960000,
#  11400000,
#  8560000,
#  5680000,
#  0,
#  15630000,
#  2850000,
#  0,
#  0,
#  13630000,
#  0,
#  0,
#  0,
#  2840000,
#  3100000,
#  0,
#  9490000,
#  0,
#  11190000,
#  16160000,
#  0,
#  7010000,
#  10940000,
#  0,
#  1090000,
#  0,
#  10340000,
#  13210000,
#  14150000,
#  18820000,
#  7080000,
#  18570000,
#  14740000,
#  0,
#  0,
#  11920000,
#  0,
#  0,
#  0,
#  0,
#  0,
#  5520000,
#  0,
#  8460000,
#  7010000,
#  7800000,
#  0,
#  19240000,
#  2270000,
#  6630000,
#  12440000,
#  17930000,
#  3800000,
#  15760000,
#  19380000,
#  6670000,
#  0,
#  9090000,
#  0,
#  18620000,
#  20290000,
#  0,
#  10610000,
#  210000,
#  0,
#  6750000,
#  15570000,
#  4950000,
#  17980000,
#  0,
#  7960000,
#  0,
#  0,
#  10090000,
#  0,
#  0,
#  4570000,
#  5950000,
#  5120000,
#  21140000,
#  11940000,
#  200000,
#  2870000,
#  1790000,
#  0,
#  4190000,
#  15970000,
#  5450000,
#  0,
#  0,
#  8480000,
#  0,
#  14750000,
#  0,
#  0,
#  1840000,
#  15410000,
#  0,
#  14190000,
#  8000000,
#  11510000,
#  9300000,
#  14230000,
#  0,
#  0,
#  14850000,
#  4010000,
#  1800000,
#  8000000,
#  0,
#  0,
#  6500000,
#  2950000,
#  3790000,
#  0,
#  15930000,
#  0,
#  14570000,
#  18000000,
#  7430000,
#  0,
#  7890000,
#  9800000,
#  14000000,
#  14210000,
#  19320000,
#  16710000,
#  5050000,
#  11070000,
#  22780000,
#  18280000,
#  5370000,
#  6480000,
#  19640000,
#  0,
#  0,
#  10260000,
#  4520000,
#  1650000,
#  21370000,
#  730000,
#  14500000,
#  9720000,
#  2960000,
#  0,
#  0,
#  0,
#  12900000,
#  16160000,
#  0,
#  1190000,
#  17000000,
#  13210000,
#  15040000,
#  18930000,
#  3740000,
#  11350000,
#  12990000,
#  8030000,
#  5240000,
#  0]

# %%
df['Paid Loans Sum'] = x

# %%
scaler = MinMaxScaler()
df['Paid Loans Sum'] = scaler.fit_transform(df['Paid Loans Sum'].reshape(-1,1))
# Out:
# C:\Users\mittr\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   """
# C:\Users\mittr\Anaconda3\lib\site-packages\sklearn\utils\validation.py:444: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
def func(arr):
    
    bias = 1
    
    arr2 = []
    for j in range(len(arr)):
        arr2.append(arr[j])
        
    arr2 = sorted(arr2)
    
    lis = []
    for i in range(len(arr2)):
        elem = bias * arr2[i]
        bias *= 2
        lis.append(elem)
    ans = sum(lis)
    return ans

df['Reference_factor'] = df['Level of Referees'].apply(func)

# %%
# Reference factor given more importance than A/c Balance + FDs
df['Reference_factor'] = df['Reference_factor'] / 12

# %%
# Reference factor given most importance [Max score = 5]
df['Paid Loans Sum'] = df['Paid Loans Sum'] * 5

# %%
df
# Out:
#        ID  A/c Bal  Fixed Deposit Active Loans Level of Referees  \
# 0    3855  4311534          98000    [6660000]            [3, 3]
# 1    8823  8335207          49000           []         [1, 3, 3]
# 2    2368  7634779          70000           []         [4, 1, 3]
# 3    7123  7351828          79000    [7210000]            [1, 4]
# 4    4286  1955267          92000           []         [4, 3, 1]
# 5    6037  6551122          45000    [1930000]                []
# 6    2542   568208          35000           []            [3, 1]
# 7    9409  3821089          58000    [1240000]         [4, 3, 3]
# 8    7333  5924078          35000           []         [2, 5, 4]
# 9    7227  6549043          71000           []                []
# 10   7024  6405684              0           []            [3, 3]
# 11   7118  2263267          85000    [9520000]                []
# 12   8113  4733874          94000           []            [5, 5]
# 13   5048  5840329          47000    [7560000]         [5, 4, 1]
# 14   8566  4083279          99000           []               [2]
# 15   6736  6470368          76000           []         [1, 1, 3]
# 16   8039  2513127          40000    [5110000]         [5, 2, 5]
# 17   3434  8696752          83000           []            [2, 5]
# 18   9856  2545371           9000    [7500000]            [3, 2]
# 19   7836  8252725          40000           []         [3, 2, 5]
# 20   9092  3354967           7000           []         [1, 1, 3]
# 21   3542  9954368          95000    [8760000]            [3, 4]
# 22   6670  1375616          78000    [7040000]               [3]
# 23   6555  1992237          88000    [4710000]                []
# 24   9696  6563642          77000    [4500000]               [1]
# 25   5974  9986480              0    [1390000]               [2]
# 26   2899   150812          99000           []         [1, 5, 1]
# 27   9303  8114220          50000           []                []
# 28   9100  3374117          41000    [6000000]               [5]
# 29   4499  6553585          85000    [4580000]            [4, 1]
# ..    ...      ...            ...          ...               ...
# 970  3631  1426639          95000    [9580000]                []
# 971  8662  2854547          62000    [5280000]            [3, 1]
# 972  5667  4665587          35000     [770000]            [4, 3]
# 973  5062  6305063          45000    [6600000]            [3, 4]
# 974  8504  9146402          23000     [670000]                []
# 975  3878  2605112          36000    [2190000]               [3]
# 976  5138  9849970          98000     [680000]         [5, 4, 2]
# 977  4181  1143935          22000    [7920000]            [4, 3]
# 978  2254  1265537          23000    [4660000]               [2]
# 979  6583  5823994          55000           []                []
# 980  9965  5268508          49000    [1210000]                []
# 981  1584  4754138          85000    [9600000]         [4, 3, 2]
# 982  9768  2259581          11000     [530000]               [4]
# 983  4343  9824938          74000           []                []
# 984  9138   812937          71000           []         [2, 5, 1]
# 985  5401  4535149          55000    [3840000]               [3]
# 986  3235  2947160          93000    [2290000]                []
# 987  3775  1027486           7000    [5410000]                []
# 988  9105  6654396           7000    [9120000]               [4]
# 989  2560  3079541          63000           []                []
# 990  8296  7161438          68000           []         [4, 4, 5]
# 991  3491  1890208          30000    [4260000]            [5, 5]
# 992  2990  1364425          48000           []                []
# 993  2671  1389794          51000     [160000]            [4, 5]
# 994  8596  5419878          10000    [6830000]                []
# 995  4375  8879545          51000           []            [2, 5]
# 996  7239  8301109           9000    [6590000]         [5, 5, 2]
# 997  9703   349074          95000           []               [4]
# 998  7774  5893888          67000           []               [3]
# 999  6555  3189338          13000           []         [5, 3, 1]
#
#                       Paid Loans     col12  Paid Loans Sum  Reference_factor
# 0                      [5420000]  0.431591        1.012706          0.750000
# 1                             []  0.829638        0.000000          1.583333
# 2                             []  0.761596        0.000000          1.916667
# 3                      [6430000]  0.734161        1.201420          0.750000
# 4                      [7810000]  0.195020        1.459268          1.916667
# 5             [2520000, 9780000]  0.650569        2.298206          0.000000
# 6    [3990000, 5710000, 4180000]  0.050403        2.593423          0.583333
# 7             [7850000, 1560000]  0.378469        1.758221          2.083333
# 8    [9130000, 3570000, 9070000]  0.586772        4.067638          2.500000
# 9                             []  0.652965        0.000000          0.000000
# 10                            []  0.631497        0.000000          0.750000
# 11            [5830000, 4030000]  0.225164        1.842302          0.000000
# 12                     [8640000]  0.473486        1.614350          1.250000
# 13                            []  0.579586        0.000000          2.416667
# 14                            []  0.408833        0.000000          0.166667
# 15                     [5110000]  0.645586        0.954783          1.250000
# 16      [100000, 10000, 4250000]  0.245680        0.814649          2.666667
# 17            [8350000, 9200000]  0.869250        3.279148          1.000000
# 18            [4340000, 5900000]  0.245804        1.913303          0.666667
# 19                     [5090000]  0.820477        0.951046          2.333333
# 20   [2150000, 8220000, 7670000]  0.326682        3.370703          1.250000
# 21            [5800000, 4220000]  0.996397        1.872197          0.916667
# 22                     [8200000]  0.135568        1.532138          0.250000
# 23                     [7080000]  0.198322        1.322870          0.000000
# 24            [4490000, 7040000]  0.655027        2.154335          0.083333
# 25            [9920000, 8890000]  0.990099        3.514574          0.166667
# 26                     [2230000]  0.015012        0.416667          1.916667
# 27                     [1290000]  0.807607        0.241031          0.000000
# 28                     [7870000]  0.332004        1.470478          0.416667
# 29                     [6420000]  0.654821        1.199552          0.750000
# ..                           ...       ...             ...               ...
# 970                    [5370000]  0.142380        1.003363          0.000000
# 971           [3040000, 3440000]  0.282075        1.210762          0.583333
# 972  [9210000, 3670000, 6760000]  0.460739        3.669656          0.916667
# 973                           []  0.625927        0.000000          0.916667
# 974                           []  0.908272        0.000000          0.000000
# 975  [5330000, 1510000, 3420000]  0.254491        1.917040          0.250000
# 976            [4060000, 460000]  0.986243        0.844544          2.500000
# 977             [1610000, 40000]  0.106758        0.308296          0.916667
# 978  [6290000, 6680000, 8400000]  0.119036        3.992900          0.166667
# 979                     [730000]  0.578752        0.136398          0.000000
# 980           [5520000, 8980000]  0.522521        2.709268          0.000000
# 981           [4810000, 4910000]  0.474614        1.816143          2.000000
# 982                    [2960000]  0.217384        0.553064          0.333333
# 983                           []  0.981332        0.000000          0.000000
# 984                           []  0.078517        0.000000          2.083333
# 985                           []  0.449679        0.000000          0.250000
# 986           [9190000, 3710000]  0.294454        2.410314          0.000000
# 987  [5850000, 6330000, 3980000]  0.093594        3.019432          0.000000
# 988                           []  0.657106        0.000000          0.333333
# 989                    [1190000]  0.304707        0.222347          0.000000
# 990           [9950000, 7050000]  0.713993        3.176383          2.666667
# 991           [7450000, 5760000]  0.182296        2.468236          1.250000
# 992           [7210000, 7830000]  0.131443        2.810164          0.000000
# 993           [8970000, 9960000]  0.134284        3.536996          1.166667
# 994                    [3740000]  0.533774        0.698804          0.000000
# 995           [3030000, 8320000]  0.884352        2.120703          1.000000
# 996           [3900000, 9090000]  0.822218        2.427130          2.666667
# 997                    [8030000]  0.034467        1.500374          0.333333
# 998                    [5240000]  0.586953        0.979073          0.250000
# 999                           []  0.310696        0.000000          2.250000
#
# [1000 rows x 9 columns]

# %%
lis = []
for x in df['Active Loans'].iteritems():
    if len(x[1]) > 0:
        lis.append((x[1][0]) / 1000000)
    else:
        lis.append(0)
lis
# Out:
# [6.66,
#  0,
#  0,
#  7.21,
#  0,
#  1.93,
#  0,
#  1.24,
#  0,
#  0,
#  0,
#  9.52,
#  0,
#  7.56,
#  0,
#  0,
#  5.11,
#  0,
#  7.5,
#  0,
#  0,
#  8.76,
#  7.04,
#  4.71,
#  4.5,
#  1.39,
#  0,
#  0,
#  6.0,
#  4.58,
#  8.37,
#  0,
#  0,
#  0,
#  4.7,
#  0,
#  6.61,
#  2.28,
#  0,
#  0,
#  0,
#  7.85,
#  0,
#  0,
#  9.45,
#  5.01,
#  1.4,
#  0,
#  9.28,
#  5.26,
#  0,
#  3.02,
#  5.07,
#  0,
#  9.14,
#  0,
#  9.06,
#  6.88,
#  6.86,
#  8.56,
#  0,
#  9.53,
#  8.4,
#  0,
#  0.56,
#  6.88,
#  0,
#  0,
#  5.79,
#  4.55,
#  0,
#  4.81,
#  0,
#  0,
#  0,
#  2.68,
#  1.7,
#  0,
#  0.92,
#  0,
#  0,
#  0,
#  4.76,
#  0,
#  0,
#  0,
#  8.39,
#  7.02,
#  9.05,
#  8.37,
#  0,
#  0,
#  5.46,
#  0,
#  0,
#  5.31,
#  0,
#  0,
#  3.41,
#  6.06,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  8.72,
#  6.01,
#  0,
#  6.91,
#  2.5,
#  0,
#  0,
#  5.07,
#  0,
#  0,
#  0,
#  1.44,
#  9.7,
#  6.06,
#  0,
#  0,
#  4.68,
#  4.84,
#  4.39,
#  0,
#  4.71,
#  9.82,
#  0,
#  7.45,
#  0,
#  0,
#  6.03,
#  0,
#  1.72,
#  1.59,
#  7.28,
#  1.32,
#  3.61,
#  0,
#  6.47,
#  6.28,
#  3.37,
#  5.36,
#  7.4,
#  0,
#  1.27,
#  0.83,
#  2.48,
#  1.78,
#  0,
#  5.91,
#  0,
#  4.51,
#  0,
#  4.67,
#  0,
#  0,
#  0,
#  8.43,
#  4.39,
#  0,
#  3.64,
#  0,
#  9.03,
#  5.82,
#  5.23,
#  3.19,
#  2.07,
#  0,
#  0,
#  0,
#  0,
#  0.38,
#  0,
#  2.8,
#  3.79,
#  0,
#  0,
#  5.89,
#  0,
#  4.16,
#  1.41,
#  0,
#  0,
#  0,
#  0,
#  9.72,
#  6.93,
#  0,
#  8.09,
#  0,
#  1.3,
#  0.48,
#  0.87,
#  8.53,
#  0,
#  0,
#  0,
#  0,
#  0,
#  6.82,
#  0,
#  9.54,
#  0,
#  9.68,
#  6.95,
#  5.9,
#  0,
#  0.25,
#  0,
#  6.88,
#  8.6,
#  0,
#  7.05,
#  0,
#  0,
#  8.49,
#  4.74,
#  0,
#  3.15,
#  6.7,
#  4.92,
#  0,
#  3.4,
#  0,
#  0,
#  0,
#  3.52,
#  4.73,
#  7.26,
#  0,
#  0,
#  0,
#  0,
#  9.21,
#  2.48,
#  0,
#  6.46,
#  0,
#  5.28,
#  9.29,
#  0,
#  0,
#  3.1,
#  0,
#  0,
#  3.99,
#  6.18,
#  0,
#  0,
#  0,
#  6.84,
#  0.75,
#  0,
#  0,
#  0,
#  8.68,
#  0,
#  0,
#  0,
#  0,
#  7.06,
#  6.7,
#  0,
#  5.36,
#  6.72,
#  0,
#  3.98,
#  0,
#  2.47,
#  0,
#  3.47,
#  9.34,
#  5.98,
#  6.82,
#  2.1,
#  0,
#  0,
#  0,
#  1.49,
#  7.54,
#  0,
#  0,
#  0.02,
#  0,
#  0,
#  7.36,
#  8.31,
#  0,
#  0,
#  0,
#  0,
#  0,
#  9.08,
#  8.47,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0.57,
#  4.6,
#  5.3,
#  0.64,
#  0,
#  0,
#  0,
#  0,
#  0,
#  8.56,
#  0,
#  0,
#  0,
#  0,
#  4.05,
#  0,
#  4.6,
#  0.05,
#  0.51,
#  0,
#  4.8,
#  0,
#  4.56,
#  3.68,
#  0,
#  0,
#  0,
#  6.71,
#  0,
#  8.68,
#  0,
#  2.12,
#  0,
#  0,
#  2.64,
#  5.83,
#  0,
#  1.15,
#  9.8,
#  3.97,
#  8.77,
#  4.47,
#  6.6,
#  0,
#  4.56,
#  9.14,
#  0,
#  3.34,
#  1.87,
#  1.38,
#  1.01,
#  1.35,
#  5.89,
#  0,
#  0,
#  0,
#  0,
#  1.31,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  9.1,
#  0,
#  3.32,
#  0,
#  1.9,
#  4.64,
#  0,
#  2.87,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  4.48,
#  0,
#  9.35,
#  0,
#  5.19,
#  3.96,
#  0,
#  0,
#  0,
#  0,
#  9.24,
#  1.21,
#  2.25,
#  0.27,
#  0,
#  6.4,
#  4.8,
#  0.34,
#  0,
#  7.58,
#  0,
#  5.41,
#  0,
#  7.25,
#  0,
#  6.38,
#  9.34,
#  6.88,
#  0,
#  0,
#  4.0,
#  0,
#  3.55,
#  0,
#  0,
#  7.68,
#  1.6,
#  0,
#  4.08,
#  0,
#  5.66,
#  0.35,
#  0,
#  2.53,
#  4.51,
#  8.02,
#  0.36,
#  0,
#  1.37,
#  0,
#  0,
#  6.17,
#  2.85,
#  6.59,
#  0,
#  5.95,
#  0,
#  0,
#  4.59,
#  3.49,
#  9.76,
#  9.67,
#  0,
#  3.0,
#  0,
#  0,
#  2.73,
#  9.58,
#  5.81,
#  1.84,
#  0,
#  5.93,
#  0,
#  3.39,
#  6.97,
#  1.3,
#  0,
#  0,
#  0,
#  9.77,
#  6.04,
#  0,
#  0,
#  5.07,
#  0,
#  8.81,
#  0,
#  0,
#  0,
#  8.12,
#  1.58,
#  8.25,
#  0,
#  0,
#  0,
#  5.52,
#  8.99,
#  0,
#  2.59,
#  4.87,
#  6.52,
#  0,
#  0,
#  3.24,
#  0.15,
#  1.54,
#  2.76,
#  6.86,
#  0,
#  5.89,
#  0,
#  3.75,
#  0,
#  6.92,
#  0,
#  0,
#  4.44,
#  0,
#  0,
#  7.71,
#  3.27,
#  5.65,
#  0,
#  0,
#  6.73,
#  3.09,
#  0,
#  0,
#  0,
#  1.94,
#  0,
#  0,
#  4.98,
#  0,
#  0,
#  3.98,
#  4.61,
#  0,
#  9.1,
#  8.52,
#  1.2,
#  0,
#  0,
#  0,
#  0,
#  0,
#  7.09,
#  4.58,
#  0,
#  0,
#  0,
#  0,
#  6.66,
#  0,
#  6.38,
#  0,
#  6.59,
#  0,
#  2.27,
#  7.47,
#  3.06,
#  6.27,
#  0,
#  7.72,
#  5.41,
#  0,
#  1.86,
#  0,
#  4.7,
#  6.57,
#  3.45,
#  0,
#  0,
#  7.21,
#  9.18,
#  1.39,
#  5.61,
#  0,
#  0,
#  0,
#  3.31,
#  1.29,
#  0,
#  5.65,
#  5.18,
#  8.07,
#  7.69,
#  7.31,
#  0,
#  0,
#  0,
#  0,
#  8.13,
#  0.55,
#  1.01,
#  0.3,
#  0,
#  7.36,
#  0,
#  7.37,
#  4.32,
#  0,
#  8.84,
#  9.62,
#  0,
#  3.24,
#  0,
#  4.18,
#  3.4,
#  0,
#  6.97,
#  0,
#  3.09,
#  6.18,
#  0,
#  0,
#  0,
#  0.3,
#  6.25,
#  0,
#  0,
#  2.17,
#  9.81,
#  6.23,
#  4.27,
#  7.36,
#  0,
#  0,
#  7.93,
#  0,
#  6.98,
#  0,
#  0,
#  0,
#  5.77,
#  0,
#  0,
#  3.51,
#  6.43,
#  0,
#  0,
#  0,
#  8.32,
#  3.18,
#  0,
#  0,
#  6.89,
#  0,
#  0,
#  1.36,
#  0,
#  5.73,
#  8.93,
#  0,
#  5.63,
#  0,
#  7.8,
#  6.0,
#  9.07,
#  0,
#  0,
#  0,
#  0,
#  9.1,
#  3.46,
#  0,
#  6.71,
#  5.66,
#  0,
#  0,
#  0,
#  0,
#  6.04,
#  0,
#  0.08,
#  0,
#  0,
#  0.97,
#  0.53,
#  2.76,
#  5.63,
#  0,
#  0,
#  0,
#  0.44,
#  5.87,
#  7.05,
#  0,
#  2.74,
#  9.51,
#  0,
#  0,
#  0,
#  8.43,
#  7.45,
#  0,
#  1.96,
#  0,
#  0,
#  0,
#  3.12,
#  0,
#  8.31,
#  4.33,
#  7.04,
#  9.23,
#  0,
#  0,
#  0,
#  0,
#  0,
#  4.14,
#  8.72,
#  4.98,
#  0,
#  0,
#  0.17,
#  5.34,
#  6.1,
#  0.2,
#  6.65,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  6.96,
#  0,
#  0,
#  0,
#  5.0,
#  0,
#  0,
#  6.5,
#  2.05,
#  0,
#  5.16,
#  0,
#  7.5,
#  9.62,
#  4.01,
#  4.96,
#  3.5,
#  0,
#  0,
#  5.17,
#  0,
#  0,
#  2.45,
#  0,
#  9.83,
#  0,
#  8.39,
#  0,
#  2.5,
#  0,
#  0,
#  0,
#  8.34,
#  5.52,
#  0,
#  0,
#  0,
#  0,
#  0,
#  7.76,
#  5.73,
#  0.14,
#  4.39,
#  7.71,
#  0,
#  5.51,
#  3.15,
#  7.88,
#  1.91,
#  1.75,
#  7.95,
#  0,
#  0,
#  0,
#  0,
#  0,
#  9.13,
#  0,
#  1.52,
#  5.33,
#  0.85,
#  9.49,
#  0,
#  4.06,
#  9.87,
#  1.55,
#  0,
#  0,
#  5.94,
#  2.51,
#  6.81,
#  0,
#  0,
#  0,
#  9.88,
#  8.71,
#  0,
#  6.32,
#  1.93,
#  0,
#  4.62,
#  0,
#  0,
#  0,
#  9.85,
#  0,
#  9.35,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  1.1,
#  4.45,
#  2.86,
#  0,
#  0,
#  8.31,
#  0,
#  0,
#  0,
#  0,
#  1.8,
#  1.79,
#  2.18,
#  0,
#  0,
#  2.46,
#  7.4,
#  1.78,
#  0.87,
#  0,
#  8.22,
#  0,
#  5.3,
#  5.87,
#  9.53,
#  3.85,
#  9.7,
#  0,
#  0,
#  3.92,
#  0,
#  0,
#  5.13,
#  5.29,
#  9.19,
#  1.08,
#  0,
#  5.83,
#  0,
#  0,
#  0,
#  5.57,
#  0.85,
#  7.81,
#  0,
#  0,
#  8.08,
#  1.01,
#  0.53,
#  1.96,
#  0,
#  0,
#  0,
#  9.29,
#  7.42,
#  3.22,
#  7.68,
#  0,
#  1.01,
#  7.42,
#  7.63,
#  0,
#  0,
#  7.12,
#  0,
#  4.47,
#  0,
#  0,
#  0,
#  0,
#  5.6,
#  6.8,
#  5.79,
#  0,
#  0,
#  0,
#  6.22,
#  1.21,
#  0.43,
#  0.2,
#  6.33,
#  0,
#  0.11,
#  0,
#  0,
#  4.36,
#  5.84,
#  8.49,
#  0,
#  6.88,
#  0,
#  5.86,
#  1.71,
#  0,
#  9.83,
#  0,
#  2.16,
#  6.94,
#  0,
#  1.04,
#  4.64,
#  1.45,
#  3.47,
#  0,
#  0,
#  0.58,
#  2.55,
#  4.13,
#  4.67,
#  0,
#  5.05,
#  7.67,
#  4.14,
#  0,
#  0,
#  3.23,
#  0,
#  0,
#  6.9,
#  0,
#  8.64,
#  2.6,
#  5.14,
#  1.25,
#  1.7,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  1.46,
#  0,
#  8.25,
#  8.79,
#  0,
#  0,
#  0,
#  0,
#  1.77,
#  2.97,
#  0,
#  0,
#  0.6,
#  1.21,
#  0.52,
#  6.02,
#  8.37,
#  2.92,
#  0.5,
#  9.5,
#  8.07,
#  0.03,
#  0,
#  0,
#  0,
#  0,
#  6.24,
#  0,
#  0,
#  3.85,
#  0,
#  6.86,
#  0,
#  5.88,
#  1.82,
#  0,
#  4.65,
#  0.76,
#  9.58,
#  5.28,
#  0.77,
#  6.6,
#  0.67,
#  2.19,
#  0.68,
#  7.92,
#  4.66,
#  0,
#  1.21,
#  9.6,
#  0.53,
#  0,
#  0,
#  3.84,
#  2.29,
#  5.41,
#  9.12,
#  0,
#  0,
#  4.26,
#  0,
#  0.16,
#  6.83,
#  0,
#  6.59,
#  0,
#  0,
#  0]

# %%
lis2 = []
for x in lis:
    new = x * -1
    lis2.append(new)

# %%
lis2
# Out:
# [-6.66,
#  0,
#  0,
#  -7.21,
#  0,
#  -1.93,
#  0,
#  -1.24,
#  0,
#  0,
#  0,
#  -9.52,
#  0,
#  -7.56,
#  0,
#  0,
#  -5.11,
#  0,
#  -7.5,
#  0,
#  0,
#  -8.76,
#  -7.04,
#  -4.71,
#  -4.5,
#  -1.39,
#  0,
#  0,
#  -6.0,
#  -4.58,
#  -8.37,
#  0,
#  0,
#  0,
#  -4.7,
#  0,
#  -6.61,
#  -2.28,
#  0,
#  0,
#  0,
#  -7.85,
#  0,
#  0,
#  -9.45,
#  -5.01,
#  -1.4,
#  0,
#  -9.28,
#  -5.26,
#  0,
#  -3.02,
#  -5.07,
#  0,
#  -9.14,
#  0,
#  -9.06,
#  -6.88,
#  -6.86,
#  -8.56,
#  0,
#  -9.53,
#  -8.4,
#  0,
#  -0.56,
#  -6.88,
#  0,
#  0,
#  -5.79,
#  -4.55,
#  0,
#  -4.81,
#  0,
#  0,
#  0,
#  -2.68,
#  -1.7,
#  0,
#  -0.92,
#  0,
#  0,
#  0,
#  -4.76,
#  0,
#  0,
#  0,
#  -8.39,
#  -7.02,
#  -9.05,
#  -8.37,
#  0,
#  0,
#  -5.46,
#  0,
#  0,
#  -5.31,
#  0,
#  0,
#  -3.41,
#  -6.06,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  -8.72,
#  -6.01,
#  0,
#  -6.91,
#  -2.5,
#  0,
#  0,
#  -5.07,
#  0,
#  0,
#  0,
#  -1.44,
#  -9.7,
#  -6.06,
#  0,
#  0,
#  -4.68,
#  -4.84,
#  -4.39,
#  0,
#  -4.71,
#  -9.82,
#  0,
#  -7.45,
#  0,
#  0,
#  -6.03,
#  0,
#  -1.72,
#  -1.59,
#  -7.28,
#  -1.32,
#  -3.61,
#  0,
#  -6.47,
#  -6.28,
#  -3.37,
#  -5.36,
#  -7.4,
#  0,
#  -1.27,
#  -0.83,
#  -2.48,
#  -1.78,
#  0,
#  -5.91,
#  0,
#  -4.51,
#  0,
#  -4.67,
#  0,
#  0,
#  0,
#  -8.43,
#  -4.39,
#  0,
#  -3.64,
#  0,
#  -9.03,
#  -5.82,
#  -5.23,
#  -3.19,
#  -2.07,
#  0,
#  0,
#  0,
#  0,
#  -0.38,
#  0,
#  -2.8,
#  -3.79,
#  0,
#  0,
#  -5.89,
#  0,
#  -4.16,
#  -1.41,
#  0,
#  0,
#  0,
#  0,
#  -9.72,
#  -6.93,
#  0,
#  -8.09,
#  0,
#  -1.3,
#  -0.48,
#  -0.87,
#  -8.53,
#  0,
#  0,
#  0,
#  0,
#  0,
#  -6.82,
#  0,
#  -9.54,
#  0,
#  -9.68,
#  -6.95,
#  -5.9,
#  0,
#  -0.25,
#  0,
#  -6.88,
#  -8.6,
#  0,
#  -7.05,
#  0,
#  0,
#  -8.49,
#  -4.74,
#  0,
#  -3.15,
#  -6.7,
#  -4.92,
#  0,
#  -3.4,
#  0,
#  0,
#  0,
#  -3.52,
#  -4.73,
#  -7.26,
#  0,
#  0,
#  0,
#  0,
#  -9.21,
#  -2.48,
#  0,
#  -6.46,
#  0,
#  -5.28,
#  -9.29,
#  0,
#  0,
#  -3.1,
#  0,
#  0,
#  -3.99,
#  -6.18,
#  0,
#  0,
#  0,
#  -6.84,
#  -0.75,
#  0,
#  0,
#  0,
#  -8.68,
#  0,
#  0,
#  0,
#  0,
#  -7.06,
#  -6.7,
#  0,
#  -5.36,
#  -6.72,
#  0,
#  -3.98,
#  0,
#  -2.47,
#  0,
#  -3.47,
#  -9.34,
#  -5.98,
#  -6.82,
#  -2.1,
#  0,
#  0,
#  0,
#  -1.49,
#  -7.54,
#  0,
#  0,
#  -0.02,
#  0,
#  0,
#  -7.36,
#  -8.31,
#  0,
#  0,
#  0,
#  0,
#  0,
#  -9.08,
#  -8.47,
#  0,
#  0,
#  0,
#  0,
#  0,
#  -0.57,
#  -4.6,
#  -5.3,
#  -0.64,
#  0,
#  0,
#  0,
#  0,
#  0,
#  -8.56,
#  0,
#  0,
#  0,
#  0,
#  -4.05,
#  0,
#  -4.6,
#  -0.05,
#  -0.51,
#  0,
#  -4.8,
#  0,
#  -4.56,
#  -3.68,
#  0,
#  0,
#  0,
#  -6.71,
#  0,
#  -8.68,
#  0,
#  -2.12,
#  0,
#  0,
#  -2.64,
#  -5.83,
#  0,
#  -1.15,
#  -9.8,
#  -3.97,
#  -8.77,
#  -4.47,
#  -6.6,
#  0,
#  -4.56,
#  -9.14,
#  0,
#  -3.34,
#  -1.87,
#  -1.38,
#  -1.01,
#  -1.35,
#  -5.89,
#  0,
#  0,
#  0,
#  0,
#  -1.31,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  -9.1,
#  0,
#  -3.32,
#  0,
#  -1.9,
#  -4.64,
#  0,
#  -2.87,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  -4.48,
#  0,
#  -9.35,
#  0,
#  -5.19,
#  -3.96,
#  0,
#  0,
#  0,
#  0,
#  -9.24,
#  -1.21,
#  -2.25,
#  -0.27,
#  0,
#  -6.4,
#  -4.8,
#  -0.34,
#  0,
#  -7.58,
#  0,
#  -5.41,
#  0,
#  -7.25,
#  0,
#  -6.38,
#  -9.34,
#  -6.88,
#  0,
#  0,
#  -4.0,
#  0,
#  -3.55,
#  0,
#  0,
#  -7.68,
#  -1.6,
#  0,
#  -4.08,
#  0,
#  -5.66,
#  -0.35,
#  0,
#  -2.53,
#  -4.51,
#  -8.02,
#  -0.36,
#  0,
#  -1.37,
#  0,
#  0,
#  -6.17,
#  -2.85,
#  -6.59,
#  0,
#  -5.95,
#  0,
#  0,
#  -4.59,
#  -3.49,
#  -9.76,
#  -9.67,
#  0,
#  -3.0,
#  0,
#  0,
#  -2.73,
#  -9.58,
#  -5.81,
#  -1.84,
#  0,
#  -5.93,
#  0,
#  -3.39,
#  -6.97,
#  -1.3,
#  0,
#  0,
#  0,
#  -9.77,
#  -6.04,
#  0,
#  0,
#  -5.07,
#  0,
#  -8.81,
#  0,
#  0,
#  0,
#  -8.12,
#  -1.58,
#  -8.25,
#  0,
#  0,
#  0,
#  -5.52,
#  -8.99,
#  0,
#  -2.59,
#  -4.87,
#  -6.52,
#  0,
#  0,
#  -3.24,
#  -0.15,
#  -1.54,
#  -2.76,
#  -6.86,
#  0,
#  -5.89,
#  0,
#  -3.75,
#  0,
#  -6.92,
#  0,
#  0,
#  -4.44,
#  0,
#  0,
#  -7.71,
#  -3.27,
#  -5.65,
#  0,
#  0,
#  -6.73,
#  -3.09,
#  0,
#  0,
#  0,
#  -1.94,
#  0,
#  0,
#  -4.98,
#  0,
#  0,
#  -3.98,
#  -4.61,
#  0,
#  -9.1,
#  -8.52,
#  -1.2,
#  0,
#  0,
#  0,
#  0,
#  0,
#  -7.09,
#  -4.58,
#  0,
#  0,
#  0,
#  0,
#  -6.66,
#  0,
#  -6.38,
#  0,
#  -6.59,
#  0,
#  -2.27,
#  -7.47,
#  -3.06,
#  -6.27,
#  0,
#  -7.72,
#  -5.41,
#  0,
#  -1.86,
#  0,
#  -4.7,
#  -6.57,
#  -3.45,
#  0,
#  0,
#  -7.21,
#  -9.18,
#  -1.39,
#  -5.61,
#  0,
#  0,
#  0,
#  -3.31,
#  -1.29,
#  0,
#  -5.65,
#  -5.18,
#  -8.07,
#  -7.69,
#  -7.31,
#  0,
#  0,
#  0,
#  0,
#  -8.13,
#  -0.55,
#  -1.01,
#  -0.3,
#  0,
#  -7.36,
#  0,
#  -7.37,
#  -4.32,
#  0,
#  -8.84,
#  -9.62,
#  0,
#  -3.24,
#  0,
#  -4.18,
#  -3.4,
#  0,
#  -6.97,
#  0,
#  -3.09,
#  -6.18,
#  0,
#  0,
#  0,
#  -0.3,
#  -6.25,
#  0,
#  0,
#  -2.17,
#  -9.81,
#  -6.23,
#  -4.27,
#  -7.36,
#  0,
#  0,
#  -7.93,
#  0,
#  -6.98,
#  0,
#  0,
#  0,
#  -5.77,
#  0,
#  0,
#  -3.51,
#  -6.43,
#  0,
#  0,
#  0,
#  -8.32,
#  -3.18,
#  0,
#  0,
#  -6.89,
#  0,
#  0,
#  -1.36,
#  0,
#  -5.73,
#  -8.93,
#  0,
#  -5.63,
#  0,
#  -7.8,
#  -6.0,
#  -9.07,
#  0,
#  0,
#  0,
#  0,
#  -9.1,
#  -3.46,
#  0,
#  -6.71,
#  -5.66,
#  0,
#  0,
#  0,
#  0,
#  -6.04,
#  0,
#  -0.08,
#  0,
#  0,
#  -0.97,
#  -0.53,
#  -2.76,
#  -5.63,
#  0,
#  0,
#  0,
#  -0.44,
#  -5.87,
#  -7.05,
#  0,
#  -2.74,
#  -9.51,
#  0,
#  0,
#  0,
#  -8.43,
#  -7.45,
#  0,
#  -1.96,
#  0,
#  0,
#  0,
#  -3.12,
#  0,
#  -8.31,
#  -4.33,
#  -7.04,
#  -9.23,
#  0,
#  0,
#  0,
#  0,
#  0,
#  -4.14,
#  -8.72,
#  -4.98,
#  0,
#  0,
#  -0.17,
#  -5.34,
#  -6.1,
#  -0.2,
#  -6.65,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  -6.96,
#  0,
#  0,
#  0,
#  -5.0,
#  0,
#  0,
#  -6.5,
#  -2.05,
#  0,
#  -5.16,
#  0,
#  -7.5,
#  -9.62,
#  -4.01,
#  -4.96,
#  -3.5,
#  0,
#  0,
#  -5.17,
#  0,
#  0,
#  -2.45,
#  0,
#  -9.83,
#  0,
#  -8.39,
#  0,
#  -2.5,
#  0,
#  0,
#  0,
#  -8.34,
#  -5.52,
#  0,
#  0,
#  0,
#  0,
#  0,
#  -7.76,
#  -5.73,
#  -0.14,
#  -4.39,
#  -7.71,
#  0,
#  -5.51,
#  -3.15,
#  -7.88,
#  -1.91,
#  -1.75,
#  -7.95,
#  0,
#  0,
#  0,
#  0,
#  0,
#  -9.13,
#  0,
#  -1.52,
#  -5.33,
#  -0.85,
#  -9.49,
#  0,
#  -4.06,
#  -9.87,
#  -1.55,
#  0,
#  0,
#  -5.94,
#  -2.51,
#  -6.81,
#  0,
#  0,
#  0,
#  -9.88,
#  -8.71,
#  0,
#  -6.32,
#  -1.93,
#  0,
#  -4.62,
#  0,
#  0,
#  0,
#  -9.85,
#  0,
#  -9.35,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  -1.1,
#  -4.45,
#  -2.86,
#  0,
#  0,
#  -8.31,
#  0,
#  0,
#  0,
#  0,
#  -1.8,
#  -1.79,
#  -2.18,
#  0,
#  0,
#  -2.46,
#  -7.4,
#  -1.78,
#  -0.87,
#  0,
#  -8.22,
#  0,
#  -5.3,
#  -5.87,
#  -9.53,
#  -3.85,
#  -9.7,
#  0,
#  0,
#  -3.92,
#  0,
#  0,
#  -5.13,
#  -5.29,
#  -9.19,
#  -1.08,
#  0,
#  -5.83,
#  0,
#  0,
#  0,
#  -5.57,
#  -0.85,
#  -7.81,
#  0,
#  0,
#  -8.08,
#  -1.01,
#  -0.53,
#  -1.96,
#  0,
#  0,
#  0,
#  -9.29,
#  -7.42,
#  -3.22,
#  -7.68,
#  0,
#  -1.01,
#  -7.42,
#  -7.63,
#  0,
#  0,
#  -7.12,
#  0,
#  -4.47,
#  0,
#  0,
#  0,
#  0,
#  -5.6,
#  -6.8,
#  -5.79,
#  0,
#  0,
#  0,
#  -6.22,
#  -1.21,
#  -0.43,
#  -0.2,
#  -6.33,
#  0,
#  -0.11,
#  0,
#  0,
#  -4.36,
#  -5.84,
#  -8.49,
#  0,
#  -6.88,
#  0,
#  -5.86,
#  -1.71,
#  0,
#  -9.83,
#  0,
#  -2.16,
#  -6.94,
#  0,
#  -1.04,
#  -4.64,
#  -1.45,
#  -3.47,
#  0,
#  0,
#  -0.58,
#  -2.55,
#  -4.13,
#  -4.67,
#  0,
#  -5.05,
#  -7.67,
#  -4.14,
#  0,
#  0,
#  -3.23,
#  0,
#  0,
#  -6.9,
#  0,
#  -8.64,
#  -2.6,
#  -5.14,
#  -1.25,
#  -1.7,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  -1.46,
#  0,
#  -8.25,
#  -8.79,
#  0,
#  0,
#  0,
#  0,
#  -1.77,
#  -2.97,
#  0,
#  0,
#  -0.6,
#  -1.21,
#  -0.52,
#  -6.02,
#  -8.37,
#  -2.92,
#  -0.5,
#  -9.5,
#  -8.07,
#  -0.03,
#  0,
#  0,
#  0,
#  0,
#  -6.24,
#  0,
#  0,
#  -3.85,
#  0,
#  -6.86,
#  0,
#  -5.88,
#  -1.82,
#  0,
#  -4.65,
#  -0.76,
#  -9.58,
#  -5.28,
#  -0.77,
#  -6.6,
#  -0.67,
#  -2.19,
#  -0.68,
#  -7.92,
#  -4.66,
#  0,
#  -1.21,
#  -9.6,
#  -0.53,
#  0,
#  0,
#  -3.84,
#  -2.29,
#  -5.41,
#  -9.12,
#  0,
#  0,
#  -4.26,
#  0,
#  -0.16,
#  -6.83,
#  0,
#  -6.59,
#  0,
#  0,
#  0]

# %%
df['penalty_active_loans'] = lis2

# %%
df
# Out:
#        ID  A/c Bal  Fixed Deposit Active Loans Level of Referees  \
# 0    3855  4311534          98000    [6660000]            [3, 3]
# 1    8823  8335207          49000           []         [1, 3, 3]
# 2    2368  7634779          70000           []         [4, 1, 3]
# 3    7123  7351828          79000    [7210000]            [1, 4]
# 4    4286  1955267          92000           []         [4, 3, 1]
# 5    6037  6551122          45000    [1930000]                []
# 6    2542   568208          35000           []            [3, 1]
# 7    9409  3821089          58000    [1240000]         [4, 3, 3]
# 8    7333  5924078          35000           []         [2, 5, 4]
# 9    7227  6549043          71000           []                []
# 10   7024  6405684              0           []            [3, 3]
# 11   7118  2263267          85000    [9520000]                []
# 12   8113  4733874          94000           []            [5, 5]
# 13   5048  5840329          47000    [7560000]         [5, 4, 1]
# 14   8566  4083279          99000           []               [2]
# 15   6736  6470368          76000           []         [1, 1, 3]
# 16   8039  2513127          40000    [5110000]         [5, 2, 5]
# 17   3434  8696752          83000           []            [2, 5]
# 18   9856  2545371           9000    [7500000]            [3, 2]
# 19   7836  8252725          40000           []         [3, 2, 5]
# 20   9092  3354967           7000           []         [1, 1, 3]
# 21   3542  9954368          95000    [8760000]            [3, 4]
# 22   6670  1375616          78000    [7040000]               [3]
# 23   6555  1992237          88000    [4710000]                []
# 24   9696  6563642          77000    [4500000]               [1]
# 25   5974  9986480              0    [1390000]               [2]
# 26   2899   150812          99000           []         [1, 5, 1]
# 27   9303  8114220          50000           []                []
# 28   9100  3374117          41000    [6000000]               [5]
# 29   4499  6553585          85000    [4580000]            [4, 1]
# ..    ...      ...            ...          ...               ...
# 970  3631  1426639          95000    [9580000]                []
# 971  8662  2854547          62000    [5280000]            [3, 1]
# 972  5667  4665587          35000     [770000]            [4, 3]
# 973  5062  6305063          45000    [6600000]            [3, 4]
# 974  8504  9146402          23000     [670000]                []
# 975  3878  2605112          36000    [2190000]               [3]
# 976  5138  9849970          98000     [680000]         [5, 4, 2]
# 977  4181  1143935          22000    [7920000]            [4, 3]
# 978  2254  1265537          23000    [4660000]               [2]
# 979  6583  5823994          55000           []                []
# 980  9965  5268508          49000    [1210000]                []
# 981  1584  4754138          85000    [9600000]         [4, 3, 2]
# 982  9768  2259581          11000     [530000]               [4]
# 983  4343  9824938          74000           []                []
# 984  9138   812937          71000           []         [2, 5, 1]
# 985  5401  4535149          55000    [3840000]               [3]
# 986  3235  2947160          93000    [2290000]                []
# 987  3775  1027486           7000    [5410000]                []
# 988  9105  6654396           7000    [9120000]               [4]
# 989  2560  3079541          63000           []                []
# 990  8296  7161438          68000           []         [4, 4, 5]
# 991  3491  1890208          30000    [4260000]            [5, 5]
# 992  2990  1364425          48000           []                []
# 993  2671  1389794          51000     [160000]            [4, 5]
# 994  8596  5419878          10000    [6830000]                []
# 995  4375  8879545          51000           []            [2, 5]
# 996  7239  8301109           9000    [6590000]         [5, 5, 2]
# 997  9703   349074          95000           []               [4]
# 998  7774  5893888          67000           []               [3]
# 999  6555  3189338          13000           []         [5, 3, 1]
#
#                       Paid Loans     col12  Paid Loans Sum  Reference_factor  \
# 0                      [5420000]  0.431591        1.012706          0.750000
# 1                             []  0.829638        0.000000          1.583333
# 2                             []  0.761596        0.000000          1.916667
# 3                      [6430000]  0.734161        1.201420          0.750000
# 4                      [7810000]  0.195020        1.459268          1.916667
# 5             [2520000, 9780000]  0.650569        2.298206          0.000000
# 6    [3990000, 5710000, 4180000]  0.050403        2.593423          0.583333
# 7             [7850000, 1560000]  0.378469        1.758221          2.083333
# 8    [9130000, 3570000, 9070000]  0.586772        4.067638          2.500000
# 9                             []  0.652965        0.000000          0.000000
# 10                            []  0.631497        0.000000          0.750000
# 11            [5830000, 4030000]  0.225164        1.842302          0.000000
# 12                     [8640000]  0.473486        1.614350          1.250000
# 13                            []  0.579586        0.000000          2.416667
# 14                            []  0.408833        0.000000          0.166667
# 15                     [5110000]  0.645586        0.954783          1.250000
# 16      [100000, 10000, 4250000]  0.245680        0.814649          2.666667
# 17            [8350000, 9200000]  0.869250        3.279148          1.000000
# 18            [4340000, 5900000]  0.245804        1.913303          0.666667
# 19                     [5090000]  0.820477        0.951046          2.333333
# 20   [2150000, 8220000, 7670000]  0.326682        3.370703          1.250000
# 21            [5800000, 4220000]  0.996397        1.872197          0.916667
# 22                     [8200000]  0.135568        1.532138          0.250000
# 23                     [7080000]  0.198322        1.322870          0.000000
# 24            [4490000, 7040000]  0.655027        2.154335          0.083333
# 25            [9920000, 8890000]  0.990099        3.514574          0.166667
# 26                     [2230000]  0.015012        0.416667          1.916667
# 27                     [1290000]  0.807607        0.241031          0.000000
# 28                     [7870000]  0.332004        1.470478          0.416667
# 29                     [6420000]  0.654821        1.199552          0.750000
# ..                           ...       ...             ...               ...
# 970                    [5370000]  0.142380        1.003363          0.000000
# 971           [3040000, 3440000]  0.282075        1.210762          0.583333
# 972  [9210000, 3670000, 6760000]  0.460739        3.669656          0.916667
# 973                           []  0.625927        0.000000          0.916667
# 974                           []  0.908272        0.000000          0.000000
# 975  [5330000, 1510000, 3420000]  0.254491        1.917040          0.250000
# 976            [4060000, 460000]  0.986243        0.844544          2.500000
# 977             [1610000, 40000]  0.106758        0.308296          0.916667
# 978  [6290000, 6680000, 8400000]  0.119036        3.992900          0.166667
# 979                     [730000]  0.578752        0.136398          0.000000
# 980           [5520000, 8980000]  0.522521        2.709268          0.000000
# 981           [4810000, 4910000]  0.474614        1.816143          2.000000
# 982                    [2960000]  0.217384        0.553064          0.333333
# 983                           []  0.981332        0.000000          0.000000
# 984                           []  0.078517        0.000000          2.083333
# 985                           []  0.449679        0.000000          0.250000
# 986           [9190000, 3710000]  0.294454        2.410314          0.000000
# 987  [5850000, 6330000, 3980000]  0.093594        3.019432          0.000000
# 988                           []  0.657106        0.000000          0.333333
# 989                    [1190000]  0.304707        0.222347          0.000000
# 990           [9950000, 7050000]  0.713993        3.176383          2.666667
# 991           [7450000, 5760000]  0.182296        2.468236          1.250000
# 992           [7210000, 7830000]  0.131443        2.810164          0.000000
# 993           [8970000, 9960000]  0.134284        3.536996          1.166667
# 994                    [3740000]  0.533774        0.698804          0.000000
# 995           [3030000, 8320000]  0.884352        2.120703          1.000000
# 996           [3900000, 9090000]  0.822218        2.427130          2.666667
# 997                    [8030000]  0.034467        1.500374          0.333333
# 998                    [5240000]  0.586953        0.979073          0.250000
# 999                           []  0.310696        0.000000          2.250000
#
#      penalty_active_loans
# 0                   -6.66
# 1                    0.00
# 2                    0.00
# 3                   -7.21
# 4                    0.00
# 5                   -1.93
# 6                    0.00
# 7                   -1.24
# 8                    0.00
# 9                    0.00
# 10                   0.00
# 11                  -9.52
# 12                   0.00
# 13                  -7.56
# 14                   0.00
# 15                   0.00
# 16                  -5.11
# 17                   0.00
# 18                  -7.50
# 19                   0.00
# 20                   0.00
# 21                  -8.76
# 22                  -7.04
# 23                  -4.71
# 24                  -4.50
# 25                  -1.39
# 26                   0.00
# 27                   0.00
# 28                  -6.00
# 29                  -4.58
# ..                    ...
# 970                 -9.58
# 971                 -5.28
# 972                 -0.77
# 973                 -6.60
# 974                 -0.67
# 975                 -2.19
# 976                 -0.68
# 977                 -7.92
# 978                 -4.66
# 979                  0.00
# 980                 -1.21
# 981                 -9.60
# 982                 -0.53
# 983                  0.00
# 984                  0.00
# 985                 -3.84
# 986                 -2.29
# 987                 -5.41
# 988                 -9.12
# 989                  0.00
# 990                  0.00
# 991                 -4.26
# 992                  0.00
# 993                 -0.16
# 994                 -6.83
# 995                  0.00
# 996                 -6.59
# 997                  0.00
# 998                  0.00
# 999                  0.00
#
# [1000 rows x 10 columns]

# %%
df['final'] = df['col12'] + df['Paid Loans Sum'] + df['Reference_factor'] + df['penalty_active_loans']

# %%
df
# Out:
#        ID  A/c Bal  Fixed Deposit Active Loans Level of Referees  \
# 0    3855  4311534          98000    [6660000]            [3, 3]
# 1    8823  8335207          49000           []         [1, 3, 3]
# 2    2368  7634779          70000           []         [4, 1, 3]
# 3    7123  7351828          79000    [7210000]            [1, 4]
# 4    4286  1955267          92000           []         [4, 3, 1]
# 5    6037  6551122          45000    [1930000]                []
# 6    2542   568208          35000           []            [3, 1]
# 7    9409  3821089          58000    [1240000]         [4, 3, 3]
# 8    7333  5924078          35000           []         [2, 5, 4]
# 9    7227  6549043          71000           []                []
# 10   7024  6405684              0           []            [3, 3]
# 11   7118  2263267          85000    [9520000]                []
# 12   8113  4733874          94000           []            [5, 5]
# 13   5048  5840329          47000    [7560000]         [5, 4, 1]
# 14   8566  4083279          99000           []               [2]
# 15   6736  6470368          76000           []         [1, 1, 3]
# 16   8039  2513127          40000    [5110000]         [5, 2, 5]
# 17   3434  8696752          83000           []            [2, 5]
# 18   9856  2545371           9000    [7500000]            [3, 2]
# 19   7836  8252725          40000           []         [3, 2, 5]
# 20   9092  3354967           7000           []         [1, 1, 3]
# 21   3542  9954368          95000    [8760000]            [3, 4]
# 22   6670  1375616          78000    [7040000]               [3]
# 23   6555  1992237          88000    [4710000]                []
# 24   9696  6563642          77000    [4500000]               [1]
# 25   5974  9986480              0    [1390000]               [2]
# 26   2899   150812          99000           []         [1, 5, 1]
# 27   9303  8114220          50000           []                []
# 28   9100  3374117          41000    [6000000]               [5]
# 29   4499  6553585          85000    [4580000]            [4, 1]
# ..    ...      ...            ...          ...               ...
# 970  3631  1426639          95000    [9580000]                []
# 971  8662  2854547          62000    [5280000]            [3, 1]
# 972  5667  4665587          35000     [770000]            [4, 3]
# 973  5062  6305063          45000    [6600000]            [3, 4]
# 974  8504  9146402          23000     [670000]                []
# 975  3878  2605112          36000    [2190000]               [3]
# 976  5138  9849970          98000     [680000]         [5, 4, 2]
# 977  4181  1143935          22000    [7920000]            [4, 3]
# 978  2254  1265537          23000    [4660000]               [2]
# 979  6583  5823994          55000           []                []
# 980  9965  5268508          49000    [1210000]                []
# 981  1584  4754138          85000    [9600000]         [4, 3, 2]
# 982  9768  2259581          11000     [530000]               [4]
# 983  4343  9824938          74000           []                []
# 984  9138   812937          71000           []         [2, 5, 1]
# 985  5401  4535149          55000    [3840000]               [3]
# 986  3235  2947160          93000    [2290000]                []
# 987  3775  1027486           7000    [5410000]                []
# 988  9105  6654396           7000    [9120000]               [4]
# 989  2560  3079541          63000           []                []
# 990  8296  7161438          68000           []         [4, 4, 5]
# 991  3491  1890208          30000    [4260000]            [5, 5]
# 992  2990  1364425          48000           []                []
# 993  2671  1389794          51000     [160000]            [4, 5]
# 994  8596  5419878          10000    [6830000]                []
# 995  4375  8879545          51000           []            [2, 5]
# 996  7239  8301109           9000    [6590000]         [5, 5, 2]
# 997  9703   349074          95000           []               [4]
# 998  7774  5893888          67000           []               [3]
# 999  6555  3189338          13000           []         [5, 3, 1]
#
#                       Paid Loans     col12  Paid Loans Sum  Reference_factor  \
# 0                      [5420000]  0.431591        1.012706          0.750000
# 1                             []  0.829638        0.000000          1.583333
# 2                             []  0.761596        0.000000          1.916667
# 3                      [6430000]  0.734161        1.201420          0.750000
# 4                      [7810000]  0.195020        1.459268          1.916667
# 5             [2520000, 9780000]  0.650569        2.298206          0.000000
# 6    [3990000, 5710000, 4180000]  0.050403        2.593423          0.583333
# 7             [7850000, 1560000]  0.378469        1.758221          2.083333
# 8    [9130000, 3570000, 9070000]  0.586772        4.067638          2.500000
# 9                             []  0.652965        0.000000          0.000000
# 10                            []  0.631497        0.000000          0.750000
# 11            [5830000, 4030000]  0.225164        1.842302          0.000000
# 12                     [8640000]  0.473486        1.614350          1.250000
# 13                            []  0.579586        0.000000          2.416667
# 14                            []  0.408833        0.000000          0.166667
# 15                     [5110000]  0.645586        0.954783          1.250000
# 16      [100000, 10000, 4250000]  0.245680        0.814649          2.666667
# 17            [8350000, 9200000]  0.869250        3.279148          1.000000
# 18            [4340000, 5900000]  0.245804        1.913303          0.666667
# 19                     [5090000]  0.820477        0.951046          2.333333
# 20   [2150000, 8220000, 7670000]  0.326682        3.370703          1.250000
# 21            [5800000, 4220000]  0.996397        1.872197          0.916667
# 22                     [8200000]  0.135568        1.532138          0.250000
# 23                     [7080000]  0.198322        1.322870          0.000000
# 24            [4490000, 7040000]  0.655027        2.154335          0.083333
# 25            [9920000, 8890000]  0.990099        3.514574          0.166667
# 26                     [2230000]  0.015012        0.416667          1.916667
# 27                     [1290000]  0.807607        0.241031          0.000000
# 28                     [7870000]  0.332004        1.470478          0.416667
# 29                     [6420000]  0.654821        1.199552          0.750000
# ..                           ...       ...             ...               ...
# 970                    [5370000]  0.142380        1.003363          0.000000
# 971           [3040000, 3440000]  0.282075        1.210762          0.583333
# 972  [9210000, 3670000, 6760000]  0.460739        3.669656          0.916667
# 973                           []  0.625927        0.000000          0.916667
# 974                           []  0.908272        0.000000          0.000000
# 975  [5330000, 1510000, 3420000]  0.254491        1.917040          0.250000
# 976            [4060000, 460000]  0.986243        0.844544          2.500000
# 977             [1610000, 40000]  0.106758        0.308296          0.916667
# 978  [6290000, 6680000, 8400000]  0.119036        3.992900          0.166667
# 979                     [730000]  0.578752        0.136398          0.000000
# 980           [5520000, 8980000]  0.522521        2.709268          0.000000
# 981           [4810000, 4910000]  0.474614        1.816143          2.000000
# 982                    [2960000]  0.217384        0.553064          0.333333
# 983                           []  0.981332        0.000000          0.000000
# 984                           []  0.078517        0.000000          2.083333
# 985                           []  0.449679        0.000000          0.250000
# 986           [9190000, 3710000]  0.294454        2.410314          0.000000
# 987  [5850000, 6330000, 3980000]  0.093594        3.019432          0.000000
# 988                           []  0.657106        0.000000          0.333333
# 989                    [1190000]  0.304707        0.222347          0.000000
# 990           [9950000, 7050000]  0.713993        3.176383          2.666667
# 991           [7450000, 5760000]  0.182296        2.468236          1.250000
# 992           [7210000, 7830000]  0.131443        2.810164          0.000000
# 993           [8970000, 9960000]  0.134284        3.536996          1.166667
# 994                    [3740000]  0.533774        0.698804          0.000000
# 995           [3030000, 8320000]  0.884352        2.120703          1.000000
# 996           [3900000, 9090000]  0.822218        2.427130          2.666667
# 997                    [8030000]  0.034467        1.500374          0.333333
# 998                    [5240000]  0.586953        0.979073          0.250000
# 999                           []  0.310696        0.000000          2.250000
#
#      penalty_active_loans     final
# 0                   -6.66 -4.465703
# 1                    0.00  2.412972
# 2                    0.00  2.678263
# 3                   -7.21 -4.524419
# 4                    0.00  3.570954
# 5                   -1.93  1.018775
# 6                    0.00  3.227160
# 7                   -1.24  2.980024
# 8                    0.00  7.154410
# 9                    0.00  0.652965
# 10                   0.00  1.381497
# 11                  -9.52 -7.452534
# 12                   0.00  3.337836
# 13                  -7.56 -4.563747
# 14                   0.00  0.575499
# 15                   0.00  2.850370
# 16                  -5.11 -1.383005
# 17                   0.00  5.148398
# 18                  -7.50 -4.674226
# 19                   0.00  4.104856
# 20                   0.00  4.947384
# 21                  -8.76 -4.974739
# 22                  -7.04 -5.122294
# 23                  -4.71 -3.188808
# 24                  -4.50 -1.607304
# 25                  -1.39  3.281340
# 26                   0.00  2.348346
# 27                   0.00  1.048639
# 28                  -6.00 -3.780851
# 29                  -4.58 -1.975627
# ..                    ...       ...
# 970                 -9.58 -8.434256
# 971                 -5.28 -3.203830
# 972                 -0.77  4.277062
# 973                 -6.60 -5.057406
# 974                 -0.67  0.238272
# 975                 -2.19  0.231531
# 976                 -0.68  3.650787
# 977                 -7.92 -6.588279
# 978                 -4.66 -0.381397
# 979                  0.00  0.715149
# 980                 -1.21  2.021789
# 981                 -9.60 -5.309242
# 982                 -0.53  0.573782
# 983                  0.00  0.981332
# 984                  0.00  2.161851
# 985                 -3.84 -3.140321
# 986                 -2.29  0.414768
# 987                 -5.41 -2.296974
# 988                 -9.12 -8.129561
# 989                  0.00  0.527054
# 990                  0.00  6.557042
# 991                 -4.26 -0.359468
# 992                  0.00  2.941608
# 993                 -0.16  4.677946
# 994                 -6.83 -5.597421
# 995                  0.00  4.005054
# 996                 -6.59 -0.673986
# 997                  0.00  1.868174
# 998                  0.00  1.816026
# 999                  0.00  2.560696
#
# [1000 rows x 11 columns]
